# %% [markdown]
# # Comandos para realização do trabalho da matéria de Big Data com uso da biblioteca PySpark.
#
# Este notebook foi projetado para guiar os alunos na realização das práticas de Big Data utilizando PySpark. Certifique-se de seguir cada etapa cuidadosamente para garantir a correta execução das atividades.
#
# Seu trabalho começará na célula 5. Execute as 4 primeiras células para iniciar a atividade.
#
# ## <font color=red>Observação importante:</font>
#
# <font color=yellow>Trabalho realizado com uso da biblioteca pandas não será aceito!</font>

# %% [markdown]
# ## Upload do arquivo `imdb-reviews-pt-br.csv` para dentro do Google Colab
#
# Aqui, você fará o download do dataset necessário para as atividades. Certifique-se de que o arquivo foi descompactado corretamente antes de prosseguir.

# %%
# !wget https://raw.githubusercontent.com/N-CPUninter/Big_Data/main/data/imdb-reviews-pt-br.zip -O imdb-reviews-pt-br.zip
# !unzip imdb-reviews-pt-br.zip
# !rm imdb-reviews-pt-br.zip
# Out:
# --2025-03-26 23:32:23--  https://raw.githubusercontent.com/N-CPUninter/Big_Data/main/data/imdb-reviews-pt-br.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49549692 (47M) [application/zip]
# Saving to: ‘imdb-reviews-pt-br.zip’
#
# imdb-reviews-pt-br. 100%[===================>]  47.25M   265MB/s    in 0.2s
#
# 2025-03-26 23:32:24 (265 MB/s) - ‘imdb-reviews-pt-br.zip’ saved [49549692/49549692]
#
# Archive:  imdb-reviews-pt-br.zip
#   inflating: imdb-reviews-pt-br.csv

# %% [markdown]
# ## Instalação manual das dependências para uso do pyspark no Google Colab
#
# Esta etapa garante que todas as bibliotecas necessárias para o PySpark sejam instaladas no Google Colab.

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.5)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# ## Importar, instanciar e criar a SparkSession
#
# A SparkSession é o ponto de entrada para usar o PySpark. Certifique-se de configurar corretamente o nome do aplicativo e o master.

# %%
from pyspark.sql import SparkSession

appName = "PySpark Trabalho de Big Data"
master = "local"

spark = SparkSession.builder.appName(appName).master(master).getOrCreate()

# %% [markdown]
# ## Criar spark dataframe do CSV utilizando o método read.csv do spark
#
# Não altere este código e use o dataframe imdb_df criado aqui em todo o seu trabalho. A criação de um dataframe diferente deste poderá causar erros na coluna sentiment e isso refletirá em erros de resposta das questões.

# %%
imdb_df = spark.read.csv('imdb-reviews-pt-br.csv',
                         header=True,
                         quote="\"",
                         escape="\"",
                         encoding="UTF-8",
                        inferSchema=True)

# %%
imdb_df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- text_en: string (nullable = true)
#  |-- text_pt: string (nullable = true)
#  |-- sentiment: string (nullable = true)

# %% [markdown]
# # Questão 1
#
# Nesta questão, você irá calcular a soma dos IDs para entradas onde o sentimento ('sentiment') é 'neg'.
#
# ### Objetivo:
# - Usar a coluna 'sentiment' como chave e somar os valores da coluna 'id'.

# %% [markdown]
# ## Criar funções de MAP:
# - Criar função para mapear o "sentiment" como chave e o "id" como valor do tipo inteiro
#
# A função map irá transformar cada linha do dataframe em uma **tupla** (chave-valor), onde:
# - Chave: coluna 'sentiment'
# - Valor: coluna 'id' convertida para inteiro.

# %%
#def map1(x):
  # Esta função deve retornar uma tupla (sentiment, id).
  # o argumento de entrada x é uma linha do dataframe imdb_df
  # com os dados em um formato semelhante à um dicionário
  # Apague a linha abaixo para iniciar seu código.

rdd = imdb_df.rdd.map(lambda row: (row["sentiment"], row["id"]))
resultados = rdd.collect()

for sentiment, id in resultados:
    print(f"Sentimento = {sentiment}, ID = {id}")
# Out:
# Sentimento = neg, ID = 1
# Sentimento = neg, ID = 2
# Sentimento = neg, ID = 3
# Sentimento = neg, ID = 4
# Sentimento = neg, ID = 5
# Sentimento = neg, ID = 6
# Sentimento = neg, ID = 7
# Sentimento = neg, ID = 8
# Sentimento = neg, ID = 9
# Sentimento = neg, ID = 10
# Sentimento = neg, ID = 11
# Sentimento = neg, ID = 12
# Sentimento = neg, ID = 13
# Sentimento = neg, ID = 14
# Sentimento = neg, ID = 15
# Sentimento = neg, ID = 16
# Sentimento = neg, ID = 17
# Sentimento = neg, ID = 18
# Sentimento = neg, ID = 19
# Sentimento = neg, ID = 20
# Sentimento = neg, ID = 21
# Sentimento = neg, ID = 22
# Sentimento = neg, ID = 23
# Sentimento = neg, ID = 24
# Sentimento = neg, ID = 25
# Sentimento = neg, ID = 26
# Sentimento = neg, ID = 27
# Sentimento = neg, ID = 28
# Sentimento = neg, ID = 29
# Sentimento = neg, ID = 30
# Sentimento = neg, ID = 31
# Sentimento = neg, ID = 32
# Sentimento = neg, ID = 33
# Sentimento = neg, ID = 34
# Sentimento = neg, ID = 35
# Sentimento = neg, ID = 36
# Sentimento = neg, ID = 37
# Sentimento = neg, ID = 38
# Sentimento = neg, ID = 39
# Sentimento = neg, ID = 40
# Sentimento = neg, ID = 41
# Sentimento = neg, ID = 42
# Sentimento = neg, ID = 43
# Sentimento = neg, ID = 44
# Sentimento = neg, ID = 45
# Sentimento = neg, ID = 46
# Sentimento = neg, ID = 47
# Sentimento = neg, ID = 48
# Sentimento = neg, ID = 49
# Sentimento = neg, ID = 50
# Sentimento = neg, ID = 51
# Sentimento = neg, ID = 52
# Sentimento = neg, ID = 53
# Sentimento = neg, ID = 54
# Sentimento = neg, ID = 55
# Sentimento = neg, ID = 56
# Sentimento = neg, ID = 57
# Sentimento = neg, ID = 58
# Sentimento = neg, ID = 59
# Sentimento = neg, ID = 60
# Sentimento = neg, ID = 61
# Sentimento = neg, ID = 62
# Sentimento = neg, ID = 63
# Sentimento = neg, ID = 64
# Sentimento = neg, ID = 65
# Sentimento = neg, ID = 66
# Sentimento = neg, ID = 67
# Sentimento = neg, ID = 68
# Sentimento = neg, ID = 69
# Sentimento = neg, ID = 70
# Sentimento = neg, ID = 71
# Sentimento = neg, ID = 72
# Sentimento = neg, ID = 73
# Sentimento = neg, ID = 74
# Sentimento = neg, ID = 75
# Sentimento = neg, ID = 76
# Sentimento = neg, ID = 77
# Sentimento = neg, ID = 78
# Sentimento = neg, ID = 79
# Sentimento = neg, ID = 80
# Sentimento = neg, ID = 81
# Sentimento = neg, ID = 82
# Sentimento = neg, ID = 83
# Sentimento = neg, ID = 84
# Sentimento = neg, ID = 85
# Sentimento = neg, ID = 86
# Sentimento = neg, ID = 87
# Sentimento = neg, ID = 88
# Sentimento = neg, ID = 89
# Sentimento = neg, ID = 90
# Sentimento = neg, ID = 91
# Sentimento = neg, ID = 92
# Sentimento = neg, ID = 93
# Sentimento = neg, ID = 94
# Sentimento = neg, ID = 95
# Sentimento = neg, ID = 96
# Sentimento = neg, ID = 97
# Sentimento = neg, ID = 98
# Sentimento = neg, ID = 99
# Sentimento = neg, ID = 100
# Sentimento = neg, ID = 101
# Sentimento = neg, ID = 102
# Sentimento = neg, ID = 103
# Sentimento = neg, ID = 104
# Sentimento = neg, ID = 105
# Sentimento = neg, ID = 106
# Sentimento = neg, ID = 107
# Sentimento = neg, ID = 108
# Sentimento = neg, ID = 109
# Sentimento = neg, ID = 110
# Sentimento = neg, ID = 111
# Sentimento = neg, ID = 112
# Sentimento = neg, ID = 113
# Sentimento = neg, ID = 114
# Sentimento = neg, ID = 115
# Sentimento = neg, ID = 116
# Sentimento = neg, ID = 117
# Sentimento = neg, ID = 118
# Sentimento = neg, ID = 119
# Sentimento = neg, ID = 120
# Sentimento = neg, ID = 121
# Sentimento = neg, ID = 122
# Sentimento = neg, ID = 123
# Sentimento = neg, ID = 124
# Sentimento = neg, ID = 125
# Sentimento = neg, ID = 126
# Sentimento = neg, ID = 127
# Sentimento = neg, ID = 128
# Sentimento = neg, ID = 129
# Sentimento = neg, ID = 130
# Sentimento = neg, ID = 131
# Sentimento = neg, ID = 132
# Sentimento = neg, ID = 133
# Sentimento = neg, ID = 134
# Sentimento = neg, ID = 135
# Sentimento = neg, ID = 136
# Sentimento = neg, ID = 137
# Sentimento = neg, ID = 138
# Sentimento = neg, ID = 139
# Sentimento = neg, ID = 140
# Sentimento = neg, ID = 141
# Sentimento = neg, ID = 142
# Sentimento = neg, ID = 143
# Sentimento = neg, ID = 144
# Sentimento = neg, ID = 145
# Sentimento = neg, ID = 146
# Sentimento = neg, ID = 147
# Sentimento = neg, ID = 148
# Sentimento = neg, ID = 149
# Sentimento = neg, ID = 150
# Sentimento = neg, ID = 151
# Sentimento = neg, ID = 152
# Sentimento = neg, ID = 153
# Sentimento = neg, ID = 154
# Sentimento = neg, ID = 155
# Sentimento = neg, ID = 156
# Sentimento = neg, ID = 157
# Sentimento = neg, ID = 158
# Sentimento = neg, ID = 159
# Sentimento = neg, ID = 160
# Sentimento = neg, ID = 161
# Sentimento = neg, ID = 162
# Sentimento = neg, ID = 163
# Sentimento = neg, ID = 164
# Sentimento = neg, ID = 165
# Sentimento = neg, ID = 166
# Sentimento = neg, ID = 167
# Sentimento = neg, ID = 168
# Sentimento = neg, ID = 169
# Sentimento = neg, ID = 170
# Sentimento = neg, ID = 171
# Sentimento = neg, ID = 172
# Sentimento = neg, ID = 173
# Sentimento = neg, ID = 174
# Sentimento = neg, ID = 175
# Sentimento = neg, ID = 176
# Sentimento = neg, ID = 177
# Sentimento = neg, ID = 178
# Sentimento = neg, ID = 179
# Sentimento = neg, ID = 180
# Sentimento = neg, ID = 181
# Sentimento = neg, ID = 182
# Sentimento = neg, ID = 183
# Sentimento = neg, ID = 184
# Sentimento = neg, ID = 185
# Sentimento = neg, ID = 186
# Sentimento = neg, ID = 187
# Sentimento = neg, ID = 188
# Sentimento = neg, ID = 189
# Sentimento = neg, ID = 190
# Sentimento = neg, ID = 191
# Sentimento = neg, ID = 192
# Sentimento = neg, ID = 193
# Sentimento = neg, ID = 194
# Sentimento = neg, ID = 195
# Sentimento = neg, ID = 196
# Sentimento = neg, ID = 197
# Sentimento = neg, ID = 198
# Sentimento = neg, ID = 199
# Sentimento = neg, ID = 200
# Sentimento = neg, ID = 201
# Sentimento = neg, ID = 202
# Sentimento = neg, ID = 203
# Sentimento = neg, ID = 204
# Sentimento = neg, ID = 205
# Sentimento = neg, ID = 206
# Sentimento = neg, ID = 207
# Sentimento = neg, ID = 208
# Sentimento = neg, ID = 209
# Sentimento = neg, ID = 210
# Sentimento = neg, ID = 211
# Sentimento = neg, ID = 212
# Sentimento = neg, ID = 213
# Sentimento = neg, ID = 214
# Sentimento = neg, ID = 215
# Sentimento = neg, ID = 216
# Sentimento = neg, ID = 217
# Sentimento = neg, ID = 218
# Sentimento = neg, ID = 219
# Sentimento = neg, ID = 220
# Sentimento = neg, ID = 221
# Sentimento = neg, ID = 222
# Sentimento = neg, ID = 223
# Sentimento = neg, ID = 224
# Sentimento = neg, ID = 225
# Sentimento = neg, ID = 226
# Sentimento = neg, ID = 227
# Sentimento = neg, ID = 228
# Sentimento = neg, ID = 229
# Sentimento = neg, ID = 230
# Sentimento = neg, ID = 231
# Sentimento = neg, ID = 232
# Sentimento = neg, ID = 233
# Sentimento = neg, ID = 234
# Sentimento = neg, ID = 235
# Sentimento = neg, ID = 236
# Sentimento = neg, ID = 237
# Sentimento = neg, ID = 238
# Sentimento = neg, ID = 239
# Sentimento = neg, ID = 240
# Sentimento = neg, ID = 241
# Sentimento = neg, ID = 242
# Sentimento = neg, ID = 243
# Sentimento = neg, ID = 244
# Sentimento = neg, ID = 245
# Sentimento = neg, ID = 246
# Sentimento = neg, ID = 247
# Sentimento = neg, ID = 248
# Sentimento = neg, ID = 249
# Sentimento = neg, ID = 250
# Sentimento = neg, ID = 251
# Sentimento = neg, ID = 252
# Sentimento = neg, ID = 253
# Sentimento = neg, ID = 254
# Sentimento = neg, ID = 255
# Sentimento = neg, ID = 256
# Sentimento = neg, ID = 257
# Sentimento = neg, ID = 258
# Sentimento = neg, ID = 259
# Sentimento = neg, ID = 260
# Sentimento = neg, ID = 261
# Sentimento = neg, ID = 262
# Sentimento = neg, ID = 263
# Sentimento = neg, ID = 264
# Sentimento = neg, ID = 265
# Sentimento = neg, ID = 266
# Sentimento = neg, ID = 267
# Sentimento = neg, ID = 268
# Sentimento = neg, ID = 269
# Sentimento = neg, ID = 270
# Sentimento = neg, ID = 271
# Sentimento = neg, ID = 272
# Sentimento = neg, ID = 273
# Sentimento = neg, ID = 274
# Sentimento = neg, ID = 275
# Sentimento = neg, ID = 276
# Sentimento = neg, ID = 277
# Sentimento = neg, ID = 278
# Sentimento = neg, ID = 279
# Sentimento = neg, ID = 280
# Sentimento = neg, ID = 281
# Sentimento = neg, ID = 282
# Sentimento = neg, ID = 283
# Sentimento = neg, ID = 284
# Sentimento = neg, ID = 285
# Sentimento = neg, ID = 286
# Sentimento = neg, ID = 287
# Sentimento = neg, ID = 288
# Sentimento = neg, ID = 289
# Sentimento = neg, ID = 290
# Sentimento = neg, ID = 291
# Sentimento = neg, ID = 292
# Sentimento = neg, ID = 293
# Sentimento = neg, ID = 294
# Sentimento = neg, ID = 295
# Sentimento = neg, ID = 296
# Sentimento = neg, ID = 297
# Sentimento = neg, ID = 298
# Sentimento = neg, ID = 299
# Sentimento = neg, ID = 300
# Sentimento = neg, ID = 301
# Sentimento = neg, ID = 302
# Sentimento = neg, ID = 303
# Sentimento = neg, ID = 304
# Sentimento = neg, ID = 305
# Sentimento = neg, ID = 306
# Sentimento = neg, ID = 307
# Sentimento = neg, ID = 308
# Sentimento = neg, ID = 309
# Sentimento = neg, ID = 310
# Sentimento = neg, ID = 311
# Sentimento = neg, ID = 312
# Sentimento = neg, ID = 313
# Sentimento = neg, ID = 314
# Sentimento = neg, ID = 315
# Sentimento = neg, ID = 316
# Sentimento = neg, ID = 317
# Sentimento = neg, ID = 318
# Sentimento = neg, ID = 319
# Sentimento = neg, ID = 320
# Sentimento = neg, ID = 321
# Sentimento = neg, ID = 322
# Sentimento = neg, ID = 323
# Sentimento = neg, ID = 324
# Sentimento = neg, ID = 325
# Sentimento = neg, ID = 326
# Sentimento = neg, ID = 327
# Sentimento = neg, ID = 328
# Sentimento = neg, ID = 329
# Sentimento = neg, ID = 330
# Sentimento = neg, ID = 331
# Sentimento = neg, ID = 332
# Sentimento = neg, ID = 333
# Sentimento = neg, ID = 334
# Sentimento = neg, ID = 335
# Sentimento = neg, ID = 336
# Sentimento = neg, ID = 337
# Sentimento = neg, ID = 338
# Sentimento = neg, ID = 339
# Sentimento = neg, ID = 340
# Sentimento = neg, ID = 341
# Sentimento = neg, ID = 342
# Sentimento = neg, ID = 343
# Sentimento = neg, ID = 344
# Sentimento = neg, ID = 345
# Sentimento = neg, ID = 346
# Sentimento = neg, ID = 347
# Sentimento = neg, ID = 348
# Sentimento = neg, ID = 349
# Sentimento = neg, ID = 350
# Sentimento = neg, ID = 351
# Sentimento = neg, ID = 352
# Sentimento = neg, ID = 353
# Sentimento = neg, ID = 354
# Sentimento = neg, ID = 355
# Sentimento = neg, ID = 356
# Sentimento = neg, ID = 357
# Sentimento = neg, ID = 358
# Sentimento = neg, ID = 359
# Sentimento = neg, ID = 360
# Sentimento = neg, ID = 361
# Sentimento = neg, ID = 362
# Sentimento = neg, ID = 363
# Sentimento = neg, ID = 364
# Sentimento = neg, ID = 365
# Sentimento = neg, ID = 366
# Sentimento = neg, ID = 367
# Sentimento = neg, ID = 368
# Sentimento = neg, ID = 369
# Sentimento = neg, ID = 370
# Sentimento = neg, ID = 371
# Sentimento = neg, ID = 372
# Sentimento = neg, ID = 373
# Sentimento = neg, ID = 374
# Sentimento = neg, ID = 375
# Sentimento = neg, ID = 376
# Sentimento = neg, ID = 377
# Sentimento = neg, ID = 378
# Sentimento = neg, ID = 379
# Sentimento = neg, ID = 380
# Sentimento = neg, ID = 381
# Sentimento = neg, ID = 382
# Sentimento = neg, ID = 383
# Sentimento = neg, ID = 384
# Sentimento = neg, ID = 385
# Sentimento = neg, ID = 386
# Sentimento = neg, ID = 387
# Sentimento = neg, ID = 388
# Sentimento = neg, ID = 389
# Sentimento = neg, ID = 390
# Sentimento = neg, ID = 391
# Sentimento = neg, ID = 392
# Sentimento = neg, ID = 393
# Sentimento = neg, ID = 394
# Sentimento = neg, ID = 395
# Sentimento = neg, ID = 396
# Sentimento = neg, ID = 397
# Sentimento = neg, ID = 398
# Sentimento = neg, ID = 399
# Sentimento = neg, ID = 400
# Sentimento = neg, ID = 401
# Sentimento = neg, ID = 402
# Sentimento = neg, ID = 403
# Sentimento = neg, ID = 404
# Sentimento = neg, ID = 405
# Sentimento = neg, ID = 406
# Sentimento = neg, ID = 407
# Sentimento = neg, ID = 408
# Sentimento = neg, ID = 409
# Sentimento = neg, ID = 410
# Sentimento = neg, ID = 411
# Sentimento = neg, ID = 412
# Sentimento = neg, ID = 413
# Sentimento = neg, ID = 414
# Sentimento = neg, ID = 415
# Sentimento = neg, ID = 416
# Sentimento = neg, ID = 417
# Sentimento = neg, ID = 418
# Sentimento = neg, ID = 419
# Sentimento = neg, ID = 420
# Sentimento = neg, ID = 421
# Sentimento = neg, ID = 422
# Sentimento = neg, ID = 423
# Sentimento = neg, ID = 424
# Sentimento = neg, ID = 425
# Sentimento = neg, ID = 426
# Sentimento = neg, ID = 427
# Sentimento = neg, ID = 428
# Sentimento = neg, ID = 429
# Sentimento = neg, ID = 430
# Sentimento = neg, ID = 431
# Sentimento = neg, ID = 432
# Sentimento = neg, ID = 433
# Sentimento = neg, ID = 434
# Sentimento = neg, ID = 435
# Sentimento = neg, ID = 436
# Sentimento = neg, ID = 437
# Sentimento = neg, ID = 438
# Sentimento = neg, ID = 439
# Sentimento = neg, ID = 440
# Sentimento = neg, ID = 441
# Sentimento = neg, ID = 442
# Sentimento = neg, ID = 443
# Sentimento = neg, ID = 444
# Sentimento = neg, ID = 445
# Sentimento = neg, ID = 446
# Sentimento = neg, ID = 447
# Sentimento = neg, ID = 448
# Sentimento = neg, ID = 449
# Sentimento = neg, ID = 450
# Sentimento = neg, ID = 451
# Sentimento = neg, ID = 452
# Sentimento = neg, ID = 453
# Sentimento = neg, ID = 454
# Sentimento = neg, ID = 455
# Sentimento = neg, ID = 456
# Sentimento = neg, ID = 457
# Sentimento = neg, ID = 458
# Sentimento = neg, ID = 459
# Sentimento = neg, ID = 460
# Sentimento = neg, ID = 461
# Sentimento = neg, ID = 462
# Sentimento = neg, ID = 463
# Sentimento = neg, ID = 464
# Sentimento = neg, ID = 465
# Sentimento = neg, ID = 466
# Sentimento = neg, ID = 467
# Sentimento = neg, ID = 468
# Sentimento = neg, ID = 469
# Sentimento = neg, ID = 470
# Sentimento = neg, ID = 471
# Sentimento = neg, ID = 472
# Sentimento = neg, ID = 473
# Sentimento = neg, ID = 474
# Sentimento = neg, ID = 475
# Sentimento = neg, ID = 476
# Sentimento = neg, ID = 477
# Sentimento = neg, ID = 478
# Sentimento = neg, ID = 479
# Sentimento = neg, ID = 480
# Sentimento = neg, ID = 481
# Sentimento = neg, ID = 482
# Sentimento = neg, ID = 483
# Sentimento = neg, ID = 484
# Sentimento = neg, ID = 485
# Sentimento = neg, ID = 486
# Sentimento = neg, ID = 487
# Sentimento = neg, ID = 488
# Sentimento = neg, ID = 489
# Sentimento = neg, ID = 490
# Sentimento = neg, ID = 491
# Sentimento = neg, ID = 492
# Sentimento = neg, ID = 493
# Sentimento = neg, ID = 494
# Sentimento = neg, ID = 495
# Sentimento = neg, ID = 496
# Sentimento = neg, ID = 497
# Sentimento = neg, ID = 498
# Sentimento = neg, ID = 499
# Sentimento = neg, ID = 500
# Sentimento = neg, ID = 501
# Sentimento = neg, ID = 502
# Sentimento = neg, ID = 503
# Sentimento = neg, ID = 504
# Sentimento = neg, ID = 505
# Sentimento = neg, ID = 506
# Sentimento = neg, ID = 507
# Sentimento = neg, ID = 508
# Sentimento = neg, ID = 509
# Sentimento = neg, ID = 510
# Sentimento = neg, ID = 511
# Sentimento = neg, ID = 512
# Sentimento = neg, ID = 513
# Sentimento = neg, ID = 514
# Sentimento = neg, ID = 515
# Sentimento = neg, ID = 516
# Sentimento = neg, ID = 517
# Sentimento = neg, ID = 518
# Sentimento = neg, ID = 519
# Sentimento = neg, ID = 520
# Sentimento = neg, ID = 521
# Sentimento = neg, ID = 522
# Sentimento = neg, ID = 523
# Sentimento = neg, ID = 524
# Sentimento = neg, ID = 525
# Sentimento = neg, ID = 526
# Sentimento = neg, ID = 527
# Sentimento = neg, ID = 528
# Sentimento = neg, ID = 529
# Sentimento = neg, ID = 530
# Sentimento = neg, ID = 531
# Sentimento = neg, ID = 532
# Sentimento = neg, ID = 533
# Sentimento = neg, ID = 534
# Sentimento = neg, ID = 535
# Sentimento = neg, ID = 536
# Sentimento = neg, ID = 537
# Sentimento = neg, ID = 538
# Sentimento = neg, ID = 539
# Sentimento = neg, ID = 540
# Sentimento = neg, ID = 541
# Sentimento = neg, ID = 542
# Sentimento = neg, ID = 543
# Sentimento = neg, ID = 544
# Sentimento = neg, ID = 545
# Sentimento = neg, ID = 546
# Sentimento = neg, ID = 547
# Sentimento = neg, ID = 548
# Sentimento = neg, ID = 549
# Sentimento = neg, ID = 550
# Sentimento = neg, ID = 551
# Sentimento = neg, ID = 552
# Sentimento = neg, ID = 553
# Sentimento = neg, ID = 554
# Sentimento = neg, ID = 555
# Sentimento = neg, ID = 556
# Sentimento = neg, ID = 557
# Sentimento = neg, ID = 558
# Sentimento = neg, ID = 559
# Sentimento = neg, ID = 560
# Sentimento = neg, ID = 561
# Sentimento = neg, ID = 562
# Sentimento = neg, ID = 563
# Sentimento = neg, ID = 564
# Sentimento = neg, ID = 565
# Sentimento = neg, ID = 566
# Sentimento = neg, ID = 567
# Sentimento = neg, ID = 568
# Sentimento = neg, ID = 569
# Sentimento = neg, ID = 570
# Sentimento = neg, ID = 571
# Sentimento = neg, ID = 572
# Sentimento = neg, ID = 573
# Sentimento = neg, ID = 574
# Sentimento = neg, ID = 575
# Sentimento = neg, ID = 576
# Sentimento = neg, ID = 577
# Sentimento = neg, ID = 578
# Sentimento = neg, ID = 579
# Sentimento = neg, ID = 580
# Sentimento = neg, ID = 581
# Sentimento = neg, ID = 582
# Sentimento = neg, ID = 583
# Sentimento = neg, ID = 584
# Sentimento = neg, ID = 585
# Sentimento = neg, ID = 586
# Sentimento = neg, ID = 587
# Sentimento = neg, ID = 588
# Sentimento = neg, ID = 589
# Sentimento = neg, ID = 590
# Sentimento = neg, ID = 591
# Sentimento = neg, ID = 592
# Sentimento = neg, ID = 593
# Sentimento = neg, ID = 594
# Sentimento = neg, ID = 595
# Sentimento = neg, ID = 596
# Sentimento = neg, ID = 597
# Sentimento = neg, ID = 598
# Sentimento = neg, ID = 599
# Sentimento = neg, ID = 600
# Sentimento = neg, ID = 601
# Sentimento = neg, ID = 602
# Sentimento = neg, ID = 603
# Sentimento = neg, ID = 604
# Sentimento = neg, ID = 605
# Sentimento = neg, ID = 606
# Sentimento = neg, ID = 607
# Sentimento = neg, ID = 608
# Sentimento = neg, ID = 609
# Sentimento = neg, ID = 610
# Sentimento = neg, ID = 611
# Sentimento = neg, ID = 612
# Sentimento = neg, ID = 613
# Sentimento = neg, ID = 614
# Sentimento = neg, ID = 615
# Sentimento = neg, ID = 616
# Sentimento = neg, ID = 617
# Sentimento = neg, ID = 618
# Sentimento = neg, ID = 619
# Sentimento = neg, ID = 620
# Sentimento = neg, ID = 621
# Sentimento = neg, ID = 622
# Sentimento = neg, ID = 623
# Sentimento = neg, ID = 624
# Sentimento = neg, ID = 625
# Sentimento = neg, ID = 626
# Sentimento = neg, ID = 627
# Sentimento = neg, ID = 628
# Sentimento = neg, ID = 629
# Sentimento = neg, ID = 630
# Sentimento = neg, ID = 631
# Sentimento = neg, ID = 632
# Sentimento = neg, ID = 633
# Sentimento = neg, ID = 634
# Sentimento = neg, ID = 635
# Sentimento = neg, ID = 636
# Sentimento = neg, ID = 637
# Sentimento = neg, ID = 638
# Sentimento = neg, ID = 639
# Sentimento = neg, ID = 640
# Sentimento = neg, ID = 641
# Sentimento = neg, ID = 642
# Sentimento = neg, ID = 643
# Sentimento = neg, ID = 644
# Sentimento = neg, ID = 645
# Sentimento = neg, ID = 646
# Sentimento = neg, ID = 647
# Sentimento = neg, ID = 648
# Sentimento = neg, ID = 649
# Sentimento = neg, ID = 650
# Sentimento = neg, ID = 651
# Sentimento = neg, ID = 652
# Sentimento = neg, ID = 653
# Sentimento = neg, ID = 654
# Sentimento = neg, ID = 655
# Sentimento = neg, ID = 656
# Sentimento = neg, ID = 657
# Sentimento = neg, ID = 658
# Sentimento = neg, ID = 659
# Sentimento = neg, ID = 660
# Sentimento = neg, ID = 661
# Sentimento = neg, ID = 662
# Sentimento = neg, ID = 663
# Sentimento = neg, ID = 664
# Sentimento = neg, ID = 665
# Sentimento = neg, ID = 666
# Sentimento = neg, ID = 667
# Sentimento = neg, ID = 668
# Sentimento = neg, ID = 669
# Sentimento = neg, ID = 670
# Sentimento = neg, ID = 671
# Sentimento = neg, ID = 672
# Sentimento = neg, ID = 673
# Sentimento = neg, ID = 674
# Sentimento = neg, ID = 675
# Sentimento = neg, ID = 676
# Sentimento = neg, ID = 677
# Sentimento = neg, ID = 678
# Sentimento = neg, ID = 679
# Sentimento = neg, ID = 680
# Sentimento = neg, ID = 681
# Sentimento = neg, ID = 682
# Sentimento = neg, ID = 683
# Sentimento = neg, ID = 684
# Sentimento = neg, ID = 685
# Sentimento = neg, ID = 686
# Sentimento = neg, ID = 687
# Sentimento = neg, ID = 688
# Sentimento = neg, ID = 689
# Sentimento = neg, ID = 690
# Sentimento = neg, ID = 691
# Sentimento = neg, ID = 692
# Sentimento = neg, ID = 693
# Sentimento = neg, ID = 694
# Sentimento = neg, ID = 695
# Sentimento = neg, ID = 696
# Sentimento = neg, ID = 697
# Sentimento = neg, ID = 698
# Sentimento = neg, ID = 699
# Sentimento = neg, ID = 700
# Sentimento = neg, ID = 701
# Sentimento = neg, ID = 702
# Sentimento = neg, ID = 703
# Sentimento = neg, ID = 704
# Sentimento = neg, ID = 705
# Sentimento = neg, ID = 706
# Sentimento = neg, ID = 707
# Sentimento = neg, ID = 708
# Sentimento = neg, ID = 709
# Sentimento = neg, ID = 710
# Sentimento = neg, ID = 711
# Sentimento = neg, ID = 712
# Sentimento = neg, ID = 713
# Sentimento = neg, ID = 714
# Sentimento = neg, ID = 715
# Sentimento = neg, ID = 716
# Sentimento = neg, ID = 717
# Sentimento = neg, ID = 718
# Sentimento = neg, ID = 719
# Sentimento = neg, ID = 720
# Sentimento = neg, ID = 721
# Sentimento = neg, ID = 722
# Sentimento = neg, ID = 723
# Sentimento = neg, ID = 724
# Sentimento = neg, ID = 725
# Sentimento = neg, ID = 726
# Sentimento = neg, ID = 727
# Sentimento = neg, ID = 728
# Sentimento = neg, ID = 729
# Sentimento = neg, ID = 730
# Sentimento = neg, ID = 731
# Sentimento = neg, ID = 732
# Sentimento = neg, ID = 733
# Sentimento = neg, ID = 734
# Sentimento = neg, ID = 735
# Sentimento = neg, ID = 736
# Sentimento = neg, ID = 737
# Sentimento = neg, ID = 738
# Sentimento = neg, ID = 739
# Sentimento = neg, ID = 740
# Sentimento = neg, ID = 741
# Sentimento = neg, ID = 742
# Sentimento = neg, ID = 743
# Sentimento = neg, ID = 744
# Sentimento = neg, ID = 745
# Sentimento = neg, ID = 746
# Sentimento = neg, ID = 747
# Sentimento = neg, ID = 748
# Sentimento = neg, ID = 749
# Sentimento = neg, ID = 750
# Sentimento = neg, ID = 751
# Sentimento = neg, ID = 752
# Sentimento = neg, ID = 753
# Sentimento = neg, ID = 754
# Sentimento = neg, ID = 755
# Sentimento = neg, ID = 756
# Sentimento = neg, ID = 757
# Sentimento = neg, ID = 758
# Sentimento = neg, ID = 759
# Sentimento = neg, ID = 760
# Sentimento = neg, ID = 761
# Sentimento = neg, ID = 762
# Sentimento = neg, ID = 763
# Sentimento = neg, ID = 764
# Sentimento = neg, ID = 765
# Sentimento = neg, ID = 766
# Sentimento = neg, ID = 767
# Sentimento = neg, ID = 768
# Sentimento = neg, ID = 769
# Sentimento = neg, ID = 770
# Sentimento = neg, ID = 771
# Sentimento = neg, ID = 772
# Sentimento = neg, ID = 773
# Sentimento = neg, ID = 774
# Sentimento = neg, ID = 775
# Sentimento = neg, ID = 776
# Sentimento = neg, ID = 777
# Sentimento = neg, ID = 778
# Sentimento = neg, ID = 779
# Sentimento = neg, ID = 780
# Sentimento = neg, ID = 781
# Sentimento = neg, ID = 782
# Sentimento = neg, ID = 783
# Sentimento = neg, ID = 784
# Sentimento = neg, ID = 785
# Sentimento = neg, ID = 786
# Sentimento = neg, ID = 787
# Sentimento = neg, ID = 788
# Sentimento = neg, ID = 789
# Sentimento = neg, ID = 790
# Sentimento = neg, ID = 791
# Sentimento = neg, ID = 792
# Sentimento = neg, ID = 793
# Sentimento = neg, ID = 794
# Sentimento = neg, ID = 795
# Sentimento = neg, ID = 796
# Sentimento = neg, ID = 797
# Sentimento = neg, ID = 798
# Sentimento = neg, ID = 799
# Sentimento = neg, ID = 800
# Sentimento = neg, ID = 801
# Sentimento = neg, ID = 802
# Sentimento = neg, ID = 803
# Sentimento = neg, ID = 804
# Sentimento = neg, ID = 805
# Sentimento = neg, ID = 806
# Sentimento = neg, ID = 807
# Sentimento = neg, ID = 808
# Sentimento = neg, ID = 809
# Sentimento = neg, ID = 810
# Sentimento = neg, ID = 811
# Sentimento = neg, ID = 812
# Sentimento = neg, ID = 813
# Sentimento = neg, ID = 814
# Sentimento = neg, ID = 815
# Sentimento = neg, ID = 816
# Sentimento = neg, ID = 817
# Sentimento = neg, ID = 818
# Sentimento = neg, ID = 819
# Sentimento = neg, ID = 820
# Sentimento = neg, ID = 821
# Sentimento = neg, ID = 822
# Sentimento = neg, ID = 823
# Sentimento = neg, ID = 824
# Sentimento = neg, ID = 825
# Sentimento = neg, ID = 826
# Sentimento = neg, ID = 827
# Sentimento = neg, ID = 828
# Sentimento = neg, ID = 829
# Sentimento = neg, ID = 830
# Sentimento = neg, ID = 831
# Sentimento = neg, ID = 832
# Sentimento = neg, ID = 833
# Sentimento = neg, ID = 834
# Sentimento = neg, ID = 835
# Sentimento = neg, ID = 836
# Sentimento = neg, ID = 837
# Sentimento = neg, ID = 838
# Sentimento = neg, ID = 839
# Sentimento = neg, ID = 840
# Sentimento = neg, ID = 841
# Sentimento = neg, ID = 842
# Sentimento = neg, ID = 843
# Sentimento = neg, ID = 844
# Sentimento = neg, ID = 845
# Sentimento = neg, ID = 846
# Sentimento = neg, ID = 847
# Sentimento = neg, ID = 848
# Sentimento = neg, ID = 849
# Sentimento = neg, ID = 850
# Sentimento = neg, ID = 851
# Sentimento = neg, ID = 852
# Sentimento = neg, ID = 853
# Sentimento = neg, ID = 854
# Sentimento = neg, ID = 855
# Sentimento = neg, ID = 856
# Sentimento = neg, ID = 857
# Sentimento = neg, ID = 858
# Sentimento = neg, ID = 859
# Sentimento = neg, ID = 860
# Sentimento = neg, ID = 861
# Sentimento = neg, ID = 862
# Sentimento = neg, ID = 863
# Sentimento = neg, ID = 864
# Sentimento = neg, ID = 865
# Sentimento = neg, ID = 866
# Sentimento = neg, ID = 867
# Sentimento = neg, ID = 868
# Sentimento = neg, ID = 869
# Sentimento = neg, ID = 870
# Sentimento = neg, ID = 871
# Sentimento = neg, ID = 872
# Sentimento = neg, ID = 873
# Sentimento = neg, ID = 874
# Sentimento = neg, ID = 875
# Sentimento = neg, ID = 876
# Sentimento = neg, ID = 877
# Sentimento = neg, ID = 878
# Sentimento = neg, ID = 879
# Sentimento = neg, ID = 880
# Sentimento = neg, ID = 881
# Sentimento = neg, ID = 882
# Sentimento = neg, ID = 883
# Sentimento = neg, ID = 884
# Sentimento = neg, ID = 885
# Sentimento = neg, ID = 886
# Sentimento = neg, ID = 887
# Sentimento = neg, ID = 888
# Sentimento = neg, ID = 889
# Sentimento = neg, ID = 890
# Sentimento = neg, ID = 891
# Sentimento = neg, ID = 892
# Sentimento = neg, ID = 893
# Sentimento = neg, ID = 894
# Sentimento = neg, ID = 895
# Sentimento = neg, ID = 896
# Sentimento = neg, ID = 897
# Sentimento = neg, ID = 898
# Sentimento = neg, ID = 899
# Sentimento = neg, ID = 900
# Sentimento = neg, ID = 901
# Sentimento = neg, ID = 902
# Sentimento = neg, ID = 903
# Sentimento = neg, ID = 904
# Sentimento = neg, ID = 905
# Sentimento = neg, ID = 906
# Sentimento = neg, ID = 907
# Sentimento = neg, ID = 908
# Sentimento = neg, ID = 909
# Sentimento = neg, ID = 910
# Sentimento = neg, ID = 911
# Sentimento = neg, ID = 912
# Sentimento = neg, ID = 913
# Sentimento = neg, ID = 914
# Sentimento = neg, ID = 915
# Sentimento = neg, ID = 916
# Sentimento = neg, ID = 917
# Sentimento = neg, ID = 918
# Sentimento = neg, ID = 919
# Sentimento = neg, ID = 920
# Sentimento = neg, ID = 921
# Sentimento = neg, ID = 922
# Sentimento = neg, ID = 923
# Sentimento = neg, ID = 924
# Sentimento = neg, ID = 925
# Sentimento = neg, ID = 926
# Sentimento = neg, ID = 927
# Sentimento = neg, ID = 928
# Sentimento = neg, ID = 929
# Sentimento = neg, ID = 930
# Sentimento = neg, ID = 931
# Sentimento = neg, ID = 932
# Sentimento = neg, ID = 933
# Sentimento = neg, ID = 934
# Sentimento = neg, ID = 935
# Sentimento = neg, ID = 936
# Sentimento = neg, ID = 937
# Sentimento = neg, ID = 938
# Sentimento = neg, ID = 939
# Sentimento = neg, ID = 940
# Sentimento = neg, ID = 941
# Sentimento = neg, ID = 942
# Sentimento = neg, ID = 943
# Sentimento = neg, ID = 944
# Sentimento = neg, ID = 945
# Sentimento = neg, ID = 946
# Sentimento = neg, ID = 947
# Sentimento = neg, ID = 948
# Sentimento = neg, ID = 949
# Sentimento = neg, ID = 950
# Sentimento = neg, ID = 951
# Sentimento = neg, ID = 952
# Sentimento = neg, ID = 953
# Sentimento = neg, ID = 954
# Sentimento = neg, ID = 955
# Sentimento = neg, ID = 956
# Sentimento = neg, ID = 957
# Sentimento = neg, ID = 958
# Sentimento = neg, ID = 959
# Sentimento = neg, ID = 960
# Sentimento = neg, ID = 961
# Sentimento = neg, ID = 962
# Sentimento = neg, ID = 963
# Sentimento = neg, ID = 964
# Sentimento = neg, ID = 965
# Sentimento = neg, ID = 966
# Sentimento = neg, ID = 967
# Sentimento = neg, ID = 968
# Sentimento = neg, ID = 969
# Sentimento = neg, ID = 970
# Sentimento = neg, ID = 971
# Sentimento = neg, ID = 972
# Sentimento = neg, ID = 973
# Sentimento = neg, ID = 974
# Sentimento = neg, ID = 975
# Sentimento = neg, ID = 976
# Sentimento = neg, ID = 977
# Sentimento = neg, ID = 978
# Sentimento = neg, ID = 979
# Sentimento = neg, ID = 980
# Sentimento = neg, ID = 981
# Sentimento = neg, ID = 982
# Sentimento = neg, ID = 983
# Sentimento = neg, ID = 984
# Sentimento = neg, ID = 985
# Sentimento = neg, ID = 986
# Sentimento = neg, ID = 987
# Sentimento = neg, ID = 988
# Sentimento = neg, ID = 989
# Sentimento = neg, ID = 990
# Sentimento = neg, ID = 991
# Sentimento = neg, ID = 992
# Sentimento = neg, ID = 993
# Sentimento = neg, ID = 994
# Sentimento = neg, ID = 995
# Sentimento = neg, ID = 996
# Sentimento = neg, ID = 997
# Sentimento = neg, ID = 998
# Sentimento = neg, ID = 999
# Sentimento = neg, ID = 1000
# Sentimento = neg, ID = 1001
# Sentimento = neg, ID = 1002
# Sentimento = neg, ID = 1003
# Sentimento = neg, ID = 1004
# Sentimento = neg, ID = 1005
# Sentimento = neg, ID = 1006
# Sentimento = neg, ID = 1007
# Sentimento = neg, ID = 1008
# Sentimento = neg, ID = 1009
# Sentimento = neg, ID = 1010
# Sentimento = neg, ID = 1011
# Sentimento = neg, ID = 1012
# Sentimento = neg, ID = 1013
# Sentimento = neg, ID = 1014
# Sentimento = neg, ID = 1015
# Sentimento = neg, ID = 1016
# Sentimento = neg, ID = 1017
# Sentimento = neg, ID = 1018
# Sentimento = neg, ID = 1019
# Sentimento = neg, ID = 1020
# Sentimento = neg, ID = 1021
# Sentimento = neg, ID = 1022
# Sentimento = neg, ID = 1023
# Sentimento = neg, ID = 1024
# Sentimento = neg, ID = 1025
# Sentimento = neg, ID = 1026
# Sentimento = neg, ID = 1027
# Sentimento = neg, ID = 1028
# Sentimento = neg, ID = 1029
# Sentimento = neg, ID = 1030
# Sentimento = neg, ID = 1031
# Sentimento = neg, ID = 1032
# Sentimento = neg, ID = 1033
# Sentimento = neg, ID = 1034
# Sentimento = neg, ID = 1035
# Sentimento = neg, ID = 1036
# Sentimento = neg, ID = 1037
# Sentimento = neg, ID = 1038
# Sentimento = neg, ID = 1039
# Sentimento = neg, ID = 1040
# Sentimento = neg, ID = 1041
# Sentimento = neg, ID = 1042
# Sentimento = neg, ID = 1043
# Sentimento = neg, ID = 1044
# Sentimento = neg, ID = 1045
# Sentimento = neg, ID = 1046
# Sentimento = neg, ID = 1047
# Sentimento = neg, ID = 1048
# Sentimento = neg, ID = 1049
# Sentimento = neg, ID = 1050
# Sentimento = neg, ID = 1051
# Sentimento = neg, ID = 1052
# Sentimento = neg, ID = 1053
# Sentimento = neg, ID = 1054
# Sentimento = neg, ID = 1055
# Sentimento = neg, ID = 1056
# Sentimento = neg, ID = 1057
# Sentimento = neg, ID = 1058
# Sentimento = neg, ID = 1059
# Sentimento = neg, ID = 1060
# Sentimento = neg, ID = 1061
# Sentimento = neg, ID = 1062
# Sentimento = neg, ID = 1063
# Sentimento = neg, ID = 1064
# Sentimento = neg, ID = 1065
# Sentimento = neg, ID = 1066
# Sentimento = neg, ID = 1067
# Sentimento = neg, ID = 1068
# Sentimento = neg, ID = 1069
# Sentimento = neg, ID = 1070
# Sentimento = neg, ID = 1071
# Sentimento = neg, ID = 1072
# Sentimento = neg, ID = 1073
# Sentimento = neg, ID = 1074
# Sentimento = neg, ID = 1075
# Sentimento = neg, ID = 1076
# Sentimento = neg, ID = 1077
# Sentimento = neg, ID = 1078
# Sentimento = neg, ID = 1079
# Sentimento = neg, ID = 1080
# Sentimento = neg, ID = 1081
# Sentimento = neg, ID = 1082
# Sentimento = neg, ID = 1083
# Sentimento = neg, ID = 1084
# Sentimento = neg, ID = 1085
# Sentimento = neg, ID = 1086
# Sentimento = neg, ID = 1087
# Sentimento = neg, ID = 1088
# Sentimento = neg, ID = 1089
# Sentimento = neg, ID = 1090
# Sentimento = neg, ID = 1091
# Sentimento = neg, ID = 1092
# Sentimento = neg, ID = 1093
# Sentimento = neg, ID = 1094
# Sentimento = neg, ID = 1095
# Sentimento = neg, ID = 1096
# Sentimento = neg, ID = 1097
# Sentimento = neg, ID = 1098
# Sentimento = neg, ID = 1099
# Sentimento = neg, ID = 1100
# Sentimento = neg, ID = 1101
# Sentimento = neg, ID = 1102
# Sentimento = neg, ID = 1103
# Sentimento = neg, ID = 1104
# Sentimento = neg, ID = 1105
# Sentimento = neg, ID = 1106
# Sentimento = neg, ID = 1107
# Sentimento = neg, ID = 1108
# Sentimento = neg, ID = 1109
# Sentimento = neg, ID = 1110
# Sentimento = neg, ID = 1111
# Sentimento = neg, ID = 1112
# Sentimento = neg, ID = 1113
# Sentimento = neg, ID = 1114
# Sentimento = neg, ID = 1115
# Sentimento = neg, ID = 1116
# Sentimento = neg, ID = 1117
# Sentimento = neg, ID = 1118
# Sentimento = neg, ID = 1119
# Sentimento = neg, ID = 1120
# Sentimento = neg, ID = 1121
# Sentimento = neg, ID = 1122
# Sentimento = neg, ID = 1123
# Sentimento = neg, ID = 1124
# Sentimento = neg, ID = 1125
# Sentimento = neg, ID = 1126
# Sentimento = neg, ID = 1127
# Sentimento = neg, ID = 1128
# Sentimento = neg, ID = 1129
# Sentimento = neg, ID = 1130
# Sentimento = neg, ID = 1131
# Sentimento = neg, ID = 1132
# Sentimento = neg, ID = 1133
# Sentimento = neg, ID = 1134
# Sentimento = neg, ID = 1135
# Sentimento = neg, ID = 1136
# Sentimento = neg, ID = 1137
# Sentimento = neg, ID = 1138
# Sentimento = neg, ID = 1139
# Sentimento = neg, ID = 1140
# Sentimento = neg, ID = 1141
# Sentimento = neg, ID = 1142
# Sentimento = neg, ID = 1143
# Sentimento = neg, ID = 1144
# Sentimento = neg, ID = 1145
# Sentimento = neg, ID = 1146
# Sentimento = neg, ID = 1147
# Sentimento = neg, ID = 1148
# Sentimento = neg, ID = 1149
# Sentimento = neg, ID = 1150
# Sentimento = neg, ID = 1151
# Sentimento = neg, ID = 1152
# Sentimento = neg, ID = 1153
# Sentimento = neg, ID = 1154
# Sentimento = neg, ID = 1155
# Sentimento = neg, ID = 1156
# Sentimento = neg, ID = 1157
# Sentimento = neg, ID = 1158
# Sentimento = neg, ID = 1159
# Sentimento = neg, ID = 1160
# Sentimento = neg, ID = 1161
# Sentimento = neg, ID = 1162
# Sentimento = neg, ID = 1163
# Sentimento = neg, ID = 1164
# Sentimento = neg, ID = 1165
# Sentimento = neg, ID = 1166
# Sentimento = neg, ID = 1167
# Sentimento = neg, ID = 1168
# Sentimento = neg, ID = 1169
# Sentimento = neg, ID = 1170
# Sentimento = neg, ID = 1171
# Sentimento = neg, ID = 1172
# Sentimento = neg, ID = 1173
# Sentimento = neg, ID = 1174
# Sentimento = neg, ID = 1175
# Sentimento = neg, ID = 1176
# Sentimento = neg, ID = 1177
# Sentimento = neg, ID = 1178
# Sentimento = neg, ID = 1179
# Sentimento = neg, ID = 1180
# Sentimento = neg, ID = 1181
# Sentimento = neg, ID = 1182
# Sentimento = neg, ID = 1183
# Sentimento = neg, ID = 1184
# Sentimento = neg, ID = 1185
# Sentimento = neg, ID = 1186
# Sentimento = neg, ID = 1187
# Sentimento = neg, ID = 1188
# Sentimento = neg, ID = 1189
# Sentimento = neg, ID = 1190
# Sentimento = neg, ID = 1191
# Sentimento = neg, ID = 1192
# Sentimento = neg, ID = 1193
# Sentimento = neg, ID = 1194
# Sentimento = neg, ID = 1195
# Sentimento = neg, ID = 1196
# Sentimento = neg, ID = 1197
# Sentimento = neg, ID = 1198
# Sentimento = neg, ID = 1199
# Sentimento = neg, ID = 1200
# Sentimento = neg, ID = 1201
# Sentimento = neg, ID = 1202
# Sentimento = neg, ID = 1203
# Sentimento = neg, ID = 1204
# Sentimento = neg, ID = 1205
# Sentimento = neg, ID = 1206
# Sentimento = neg, ID = 1207
# Sentimento = neg, ID = 1208
# Sentimento = neg, ID = 1209
# Sentimento = neg, ID = 1210
# Sentimento = neg, ID = 1211
# Sentimento = neg, ID = 1212
# Sentimento = neg, ID = 1213
# Sentimento = neg, ID = 1214
# Sentimento = neg, ID = 1215
# Sentimento = neg, ID = 1216
# Sentimento = neg, ID = 1217
# Sentimento = neg, ID = 1218
# Sentimento = neg, ID = 1219
# Sentimento = neg, ID = 1220
# Sentimento = neg, ID = 1221
# Sentimento = neg, ID = 1222
# Sentimento = neg, ID = 1223
# Sentimento = neg, ID = 1224
# Sentimento = neg, ID = 1225
# Sentimento = neg, ID = 1226
# Sentimento = neg, ID = 1227
# Sentimento = neg, ID = 1228
# Sentimento = neg, ID = 1229
# Sentimento = neg, ID = 1230
# Sentimento = neg, ID = 1231
# Sentimento = neg, ID = 1232
# Sentimento = neg, ID = 1233
# Sentimento = neg, ID = 1234
# Sentimento = neg, ID = 1235
# Sentimento = neg, ID = 1236
# Sentimento = neg, ID = 1237
# Sentimento = neg, ID = 1238
# Sentimento = neg, ID = 1239
# Sentimento = neg, ID = 1240
# Sentimento = neg, ID = 1241
# Sentimento = neg, ID = 1242
# Sentimento = neg, ID = 1243
# Sentimento = neg, ID = 1244
# Sentimento = neg, ID = 1245
# Sentimento = neg, ID = 1246
# Sentimento = neg, ID = 1247
# Sentimento = neg, ID = 1248
# Sentimento = neg, ID = 1249
# Sentimento = neg, ID = 1250
# Sentimento = neg, ID = 1251
# Sentimento = neg, ID = 1252
# Sentimento = neg, ID = 1253
# Sentimento = neg, ID = 1254
# Sentimento = neg, ID = 1255
# Sentimento = neg, ID = 1256
# Sentimento = neg, ID = 1257
# Sentimento = neg, ID = 1258
# Sentimento = neg, ID = 1259
# Sentimento = neg, ID = 1260
# Sentimento = neg, ID = 1261
# Sentimento = neg, ID = 1262
# Sentimento = neg, ID = 1263
# Sentimento = neg, ID = 1264
# Sentimento = neg, ID = 1265
# Sentimento = neg, ID = 1266
# Sentimento = neg, ID = 1267
# Sentimento = neg, ID = 1268
# Sentimento = neg, ID = 1269
# Sentimento = neg, ID = 1270
# Sentimento = neg, ID = 1271
# Sentimento = neg, ID = 1272
# Sentimento = neg, ID = 1273
# Sentimento = neg, ID = 1274
# Sentimento = neg, ID = 1275
# Sentimento = neg, ID = 1276
# Sentimento = neg, ID = 1277
# Sentimento = neg, ID = 1278
# Sentimento = neg, ID = 1279
# Sentimento = neg, ID = 1280
# Sentimento = neg, ID = 1281
# Sentimento = neg, ID = 1282
# Sentimento = neg, ID = 1283
# Sentimento = neg, ID = 1284
# Sentimento = neg, ID = 1285
# Sentimento = neg, ID = 1286
# Sentimento = neg, ID = 1287
# Sentimento = neg, ID = 1288
# Sentimento = neg, ID = 1289
# Sentimento = neg, ID = 1290
# Sentimento = neg, ID = 1291
# Sentimento = neg, ID = 1292
# Sentimento = neg, ID = 1293
# Sentimento = neg, ID = 1294
# Sentimento = neg, ID = 1295
# Sentimento = neg, ID = 1296
# Sentimento = neg, ID = 1297
# Sentimento = neg, ID = 1298
# Sentimento = neg, ID = 1299
# Sentimento = neg, ID = 1300
# Sentimento = neg, ID = 1301
# Sentimento = neg, ID = 1302
# Sentimento = neg, ID = 1303
# Sentimento = neg, ID = 1304
# Sentimento = neg, ID = 1305
# Sentimento = neg, ID = 1306
# Sentimento = neg, ID = 1307
# Sentimento = neg, ID = 1308
# Sentimento = neg, ID = 1309
# Sentimento = neg, ID = 1310
# Sentimento = neg, ID = 1311
# Sentimento = neg, ID = 1312
# Sentimento = neg, ID = 1313
# Sentimento = neg, ID = 1314
# Sentimento = neg, ID = 1315
# Sentimento = neg, ID = 1316
# Sentimento = neg, ID = 1317
# Sentimento = neg, ID = 1318
# Sentimento = neg, ID = 1319
# Sentimento = neg, ID = 1320
# Sentimento = neg, ID = 1321
# Sentimento = neg, ID = 1322
# Sentimento = neg, ID = 1323
# Sentimento = neg, ID = 1324
# Sentimento = neg, ID = 1325
# Sentimento = neg, ID = 1326
# Sentimento = neg, ID = 1327
# Sentimento = neg, ID = 1328
# Sentimento = neg, ID = 1329
# Sentimento = neg, ID = 1330
# Sentimento = neg, ID = 1331
# Sentimento = neg, ID = 1332
# Sentimento = neg, ID = 1333
# Sentimento = neg, ID = 1334
# Sentimento = neg, ID = 1335
# Sentimento = neg, ID = 1336
# Sentimento = neg, ID = 1337
# Sentimento = neg, ID = 1338
# Sentimento = neg, ID = 1339
# Sentimento = neg, ID = 1340
# Sentimento = neg, ID = 1341
# Sentimento = neg, ID = 1342
# Sentimento = neg, ID = 1343
# Sentimento = neg, ID = 1344
# Sentimento = neg, ID = 1345
# Sentimento = neg, ID = 1346
# Sentimento = neg, ID = 1347
# Sentimento = neg, ID = 1348
# Sentimento = neg, ID = 1349
# Sentimento = neg, ID = 1350
# Sentimento = neg, ID = 1351
# Sentimento = neg, ID = 1352
# Sentimento = neg, ID = 1353
# Sentimento = neg, ID = 1354
# Sentimento = neg, ID = 1355
# Sentimento = neg, ID = 1356
# Sentimento = neg, ID = 1357
# Sentimento = neg, ID = 1358
# Sentimento = neg, ID = 1359
# Sentimento = neg, ID = 1360
# Sentimento = neg, ID = 1361
# Sentimento = neg, ID = 1362
# Sentimento = neg, ID = 1363
# Sentimento = neg, ID = 1364
# Sentimento = neg, ID = 1365
# Sentimento = neg, ID = 1366
# Sentimento = neg, ID = 1367
# Sentimento = neg, ID = 1368
# Sentimento = neg, ID = 1369
# Sentimento = neg, ID = 1370
# Sentimento = neg, ID = 1371
# Sentimento = neg, ID = 1372
# Sentimento = neg, ID = 1373
# Sentimento = neg, ID = 1374
# Sentimento = neg, ID = 1375
# Sentimento = neg, ID = 1376
# Sentimento = neg, ID = 1377
# Sentimento = neg, ID = 1378
# Sentimento = neg, ID = 1379
# Sentimento = neg, ID = 1380
# Sentimento = neg, ID = 1381
# Sentimento = neg, ID = 1382
# Sentimento = neg, ID = 1383
# Sentimento = neg, ID = 1384
# Sentimento = neg, ID = 1385
# Sentimento = neg, ID = 1386
# Sentimento = neg, ID = 1387
# Sentimento = neg, ID = 1388
# Sentimento = neg, ID = 1389
# Sentimento = neg, ID = 1390
# Sentimento = neg, ID = 1391
# Sentimento = neg, ID = 1392
# Sentimento = neg, ID = 1393
# Sentimento = neg, ID = 1394
# Sentimento = neg, ID = 1395
# Sentimento = neg, ID = 1396
# Sentimento = neg, ID = 1397
# Sentimento = neg, ID = 1398
# Sentimento = neg, ID = 1399
# Sentimento = neg, ID = 1400
# Sentimento = neg, ID = 1401
# Sentimento = neg, ID = 1402
# Sentimento = neg, ID = 1403
# Sentimento = neg, ID = 1404
# Sentimento = neg, ID = 1405
# Sentimento = neg, ID = 1406
# Sentimento = neg, ID = 1407
# Sentimento = neg, ID = 1408
# Sentimento = neg, ID = 1409
# Sentimento = neg, ID = 1410
# Sentimento = neg, ID = 1411
# Sentimento = neg, ID = 1412
# Sentimento = neg, ID = 1413
# Sentimento = neg, ID = 1414
# Sentimento = neg, ID = 1415
# Sentimento = neg, ID = 1416
# Sentimento = neg, ID = 1417
# Sentimento = neg, ID = 1418
# Sentimento = neg, ID = 1419
# Sentimento = neg, ID = 1420
# Sentimento = neg, ID = 1421
# Sentimento = neg, ID = 1422
# Sentimento = neg, ID = 1423
# Sentimento = neg, ID = 1424
# Sentimento = neg, ID = 1425
# Sentimento = neg, ID = 1426
# Sentimento = neg, ID = 1427
# Sentimento = neg, ID = 1428
# Sentimento = neg, ID = 1429
# Sentimento = neg, ID = 1430
# Sentimento = neg, ID = 1431
# Sentimento = neg, ID = 1432
# Sentimento = neg, ID = 1433
# Sentimento = neg, ID = 1434
# Sentimento = neg, ID = 1435
# Sentimento = neg, ID = 1436
# Sentimento = neg, ID = 1437
# Sentimento = neg, ID = 1438
# Sentimento = neg, ID = 1439
# Sentimento = neg, ID = 1440
# Sentimento = neg, ID = 1441
# Sentimento = neg, ID = 1442
# Sentimento = neg, ID = 1443
# Sentimento = neg, ID = 1444
# Sentimento = neg, ID = 1445
# Sentimento = neg, ID = 1446
# Sentimento = neg, ID = 1447
# Sentimento = neg, ID = 1448
# Sentimento = neg, ID = 1449
# Sentimento = neg, ID = 1450
# Sentimento = neg, ID = 1451
# Sentimento = neg, ID = 1452
# Sentimento = neg, ID = 1453
# Sentimento = neg, ID = 1454
# Sentimento = neg, ID = 1455
# Sentimento = neg, ID = 1456
# Sentimento = neg, ID = 1457
# Sentimento = neg, ID = 1458
# Sentimento = neg, ID = 1459
# Sentimento = neg, ID = 1460
# Sentimento = neg, ID = 1461
# Sentimento = neg, ID = 1462
# Sentimento = neg, ID = 1463
# Sentimento = neg, ID = 1464
# Sentimento = neg, ID = 1465
# Sentimento = neg, ID = 1466
# Sentimento = neg, ID = 1467
# Sentimento = neg, ID = 1468
# Sentimento = neg, ID = 1469
# Sentimento = neg, ID = 1470
# Sentimento = neg, ID = 1471
# Sentimento = neg, ID = 1472
# Sentimento = neg, ID = 1473
# Sentimento = neg, ID = 1474
# Sentimento = neg, ID = 1475
# Sentimento = neg, ID = 1476
# Sentimento = neg, ID = 1477
# Sentimento = neg, ID = 1478
# Sentimento = neg, ID = 1479
# Sentimento = neg, ID = 1480
# Sentimento = neg, ID = 1481
# Sentimento = neg, ID = 1482
# Sentimento = neg, ID = 1483
# Sentimento = neg, ID = 1484
# Sentimento = neg, ID = 1485
# Sentimento = neg, ID = 1486
# Sentimento = neg, ID = 1487
# Sentimento = neg, ID = 1488
# Sentimento = neg, ID = 1489
# Sentimento = neg, ID = 1490
# Sentimento = neg, ID = 1491
# Sentimento = neg, ID = 1492
# Sentimento = neg, ID = 1493
# Sentimento = neg, ID = 1494
# Sentimento = neg, ID = 1495
# Sentimento = neg, ID = 1496
# Sentimento = neg, ID = 1497
# Sentimento = neg, ID = 1498
# Sentimento = neg, ID = 1499
# Sentimento = neg, ID = 1500
# Sentimento = neg, ID = 1501
# Sentimento = neg, ID = 1502
# Sentimento = neg, ID = 1503
# Sentimento = neg, ID = 1504
# Sentimento = neg, ID = 1505
# Sentimento = neg, ID = 1506
# Sentimento = neg, ID = 1507
# Sentimento = neg, ID = 1508
# Sentimento = neg, ID = 1509
# Sentimento = neg, ID = 1510
# Sentimento = neg, ID = 1511
# Sentimento = neg, ID = 1512
# Sentimento = neg, ID = 1513
# Sentimento = neg, ID = 1514
# Sentimento = neg, ID = 1515
# Sentimento = neg, ID = 1516
# Sentimento = neg, ID = 1517
# Sentimento = neg, ID = 1518
# Sentimento = neg, ID = 1519
# Sentimento = neg, ID = 1520
# Sentimento = neg, ID = 1521
# Sentimento = neg, ID = 1522
# Sentimento = neg, ID = 1523
# Sentimento = neg, ID = 1524
# Sentimento = neg, ID = 1525
# Sentimento = neg, ID = 1526
# Sentimento = neg, ID = 1527
# Sentimento = neg, ID = 1528
# Sentimento = neg, ID = 1529
# Sentimento = neg, ID = 1530
# Sentimento = neg, ID = 1531
# Sentimento = neg, ID = 1532
# Sentimento = neg, ID = 1533
# Sentimento = neg, ID = 1534
# Sentimento = neg, ID = 1535
# Sentimento = neg, ID = 1536
# Sentimento = neg, ID = 1537
# Sentimento = neg, ID = 1538
# Sentimento = neg, ID = 1539
# Sentimento = neg, ID = 1540
# Sentimento = neg, ID = 1541
# Sentimento = neg, ID = 1542
# Sentimento = neg, ID = 1543
# Sentimento = neg, ID = 1544
# Sentimento = neg, ID = 1545
# Sentimento = neg, ID = 1546
# Sentimento = neg, ID = 1547
# Sentimento = neg, ID = 1548
# Sentimento = neg, ID = 1549
# Sentimento = neg, ID = 1550
# Sentimento = neg, ID = 1551
# Sentimento = neg, ID = 1552
# Sentimento = neg, ID = 1553
# Sentimento = neg, ID = 1554
# Sentimento = neg, ID = 1555
# Sentimento = neg, ID = 1556
# Sentimento = neg, ID = 1557
# Sentimento = neg, ID = 1558
# Sentimento = neg, ID = 1559
# Sentimento = neg, ID = 1560
# Sentimento = neg, ID = 1561
# Sentimento = neg, ID = 1562
# Sentimento = neg, ID = 1563
# Sentimento = neg, ID = 1564
# Sentimento = neg, ID = 1565
# Sentimento = neg, ID = 1566
# Sentimento = neg, ID = 1567
# Sentimento = neg, ID = 1568
# Sentimento = neg, ID = 1569
# Sentimento = neg, ID = 1570
# Sentimento = neg, ID = 1571
# Sentimento = neg, ID = 1572
# Sentimento = neg, ID = 1573
# Sentimento = neg, ID = 1574
# Sentimento = neg, ID = 1575
# Sentimento = neg, ID = 1576
# Sentimento = neg, ID = 1577
# Sentimento = neg, ID = 1578
# Sentimento = neg, ID = 1579
# Sentimento = neg, ID = 1580
# Sentimento = neg, ID = 1581
# Sentimento = neg, ID = 1582
# Sentimento = neg, ID = 1583
# Sentimento = neg, ID = 1584
# Sentimento = neg, ID = 1585
# Sentimento = neg, ID = 1586
# Sentimento = neg, ID = 1587
# Sentimento = neg, ID = 1588
# Sentimento = neg, ID = 1589
# Sentimento = neg, ID = 1590
# Sentimento = neg, ID = 1591
# Sentimento = neg, ID = 1592
# Sentimento = neg, ID = 1593
# Sentimento = neg, ID = 1594
# Sentimento = neg, ID = 1595
# Sentimento = neg, ID = 1596
# Sentimento = neg, ID = 1597
# Sentimento = neg, ID = 1598
# Sentimento = neg, ID = 1599
# Sentimento = neg, ID = 1600
# Sentimento = neg, ID = 1601
# Sentimento = neg, ID = 1602
# Sentimento = neg, ID = 1603
# Sentimento = neg, ID = 1604
# Sentimento = neg, ID = 1605
# Sentimento = neg, ID = 1606
# Sentimento = neg, ID = 1607
# Sentimento = neg, ID = 1608
# Sentimento = neg, ID = 1609
# Sentimento = neg, ID = 1610
# Sentimento = neg, ID = 1611
# Sentimento = neg, ID = 1612
# Sentimento = neg, ID = 1613
# Sentimento = neg, ID = 1614
# Sentimento = neg, ID = 1615
# Sentimento = neg, ID = 1616
# Sentimento = neg, ID = 1617
# Sentimento = neg, ID = 1618
# Sentimento = neg, ID = 1619
# Sentimento = neg, ID = 1620
# Sentimento = neg, ID = 1621
# Sentimento = neg, ID = 1622
# Sentimento = neg, ID = 1623
# Sentimento = neg, ID = 1624
# Sentimento = neg, ID = 1625
# Sentimento = neg, ID = 1626
# Sentimento = neg, ID = 1627
# Sentimento = neg, ID = 1628
# Sentimento = neg, ID = 1629
# Sentimento = neg, ID = 1630
# Sentimento = neg, ID = 1631
# Sentimento = neg, ID = 1632
# Sentimento = neg, ID = 1633
# Sentimento = neg, ID = 1634
# Sentimento = neg, ID = 1635
# Sentimento = neg, ID = 1636
# Sentimento = neg, ID = 1637
# Sentimento = neg, ID = 1638
# Sentimento = neg, ID = 1639
# Sentimento = neg, ID = 1640
# Sentimento = neg, ID = 1641
# Sentimento = neg, ID = 1642
# Sentimento = neg, ID = 1643
# Sentimento = neg, ID = 1644
# Sentimento = neg, ID = 1645
# Sentimento = neg, ID = 1646
# Sentimento = neg, ID = 1647
# Sentimento = neg, ID = 1648
# Sentimento = neg, ID = 1649
# Sentimento = neg, ID = 1650
# Sentimento = neg, ID = 1651
# Sentimento = neg, ID = 1652
# Sentimento = neg, ID = 1653
# Sentimento = neg, ID = 1654
# Sentimento = neg, ID = 1655
# Sentimento = neg, ID = 1656
# Sentimento = neg, ID = 1657
# Sentimento = neg, ID = 1658
# Sentimento = neg, ID = 1659
# Sentimento = neg, ID = 1660
# Sentimento = neg, ID = 1661
# Sentimento = neg, ID = 1662
# Sentimento = neg, ID = 1663
# Sentimento = neg, ID = 1664
# Sentimento = neg, ID = 1665
# Sentimento = neg, ID = 1666
# Sentimento = neg, ID = 1667
# Sentimento = neg, ID = 1668
# Sentimento = neg, ID = 1669
# Sentimento = neg, ID = 1670
# Sentimento = neg, ID = 1671
# Sentimento = neg, ID = 1672
# Sentimento = neg, ID = 1673
# Sentimento = neg, ID = 1674
# Sentimento = neg, ID = 1675
# Sentimento = neg, ID = 1676
# Sentimento = neg, ID = 1677
# Sentimento = neg, ID = 1678
# Sentimento = neg, ID = 1679
# Sentimento = neg, ID = 1680
# Sentimento = neg, ID = 1681
# Sentimento = neg, ID = 1682
# Sentimento = neg, ID = 1683
# Sentimento = neg, ID = 1684
# Sentimento = neg, ID = 1685
# Sentimento = neg, ID = 1686
# Sentimento = neg, ID = 1687
# Sentimento = neg, ID = 1688
# Sentimento = neg, ID = 1689
# Sentimento = neg, ID = 1690
# Sentimento = neg, ID = 1691
# Sentimento = neg, ID = 1692
# Sentimento = neg, ID = 1693
# Sentimento = neg, ID = 1694
# Sentimento = neg, ID = 1695
# Sentimento = neg, ID = 1696
# Sentimento = neg, ID = 1697
# Sentimento = neg, ID = 1698
# Sentimento = neg, ID = 1699
# Sentimento = neg, ID = 1700
# Sentimento = neg, ID = 1701
# Sentimento = neg, ID = 1702
# Sentimento = neg, ID = 1703
# Sentimento = neg, ID = 1704
# Sentimento = neg, ID = 1705
# Sentimento = neg, ID = 1706
# Sentimento = neg, ID = 1707
# Sentimento = neg, ID = 1708
# Sentimento = neg, ID = 1709
# Sentimento = neg, ID = 1710
# Sentimento = neg, ID = 1711
# Sentimento = neg, ID = 1712
# Sentimento = neg, ID = 1713
# Sentimento = neg, ID = 1714
# Sentimento = neg, ID = 1715
# Sentimento = neg, ID = 1716
# Sentimento = neg, ID = 1717
# Sentimento = neg, ID = 1718
# Sentimento = neg, ID = 1719
# Sentimento = neg, ID = 1720
# Sentimento = neg, ID = 1721
# Sentimento = neg, ID = 1722
# Sentimento = neg, ID = 1723
# Sentimento = neg, ID = 1724
# Sentimento = neg, ID = 1725
# Sentimento = neg, ID = 1726
# Sentimento = neg, ID = 1727
# Sentimento = neg, ID = 1728
# Sentimento = neg, ID = 1729
# Sentimento = neg, ID = 1730
# Sentimento = neg, ID = 1731
# Sentimento = neg, ID = 1732
# Sentimento = neg, ID = 1733
# Sentimento = neg, ID = 1734
# Sentimento = neg, ID = 1735
# Sentimento = neg, ID = 1736
# Sentimento = neg, ID = 1737
# Sentimento = neg, ID = 1738
# Sentimento = neg, ID = 1739
# Sentimento = neg, ID = 1740
# Sentimento = neg, ID = 1741
# Sentimento = neg, ID = 1742
# Sentimento = neg, ID = 1743
# Sentimento = neg, ID = 1744
# Sentimento = neg, ID = 1745
# Sentimento = neg, ID = 1746
# Sentimento = neg, ID = 1747
# Sentimento = neg, ID = 1748
# Sentimento = neg, ID = 1749
# Sentimento = neg, ID = 1750
# Sentimento = neg, ID = 1751
# Sentimento = neg, ID = 1752
# Sentimento = neg, ID = 1753
# ...
# Sentimento = pos, ID = 48910
# Sentimento = pos, ID = 48911
# Sentimento = pos, ID = 48912
# Sentimento = pos, ID = 48913
# Sentimento = pos, ID = 48914
# Sentimento = pos, ID = 48915
# Sentimento = pos, ID = 48916
# Sentimento = pos, ID = 48917
# Sentimento = pos, ID = 48918
# Sentimento = pos, ID = 48919
# Sentimento = pos, ID = 48920
# Sentimento = pos, ID = 48921
# Sentimento = pos, ID = 48922
# Sentimento = pos, ID = 48923
# Sentimento = pos, ID = 48924
# Sentimento = pos, ID = 48925
# Sentimento = pos, ID = 48926
# Sentimento = pos, ID = 48927
# Sentimento = pos, ID = 48928
# Sentimento = pos, ID = 48929
# Sentimento = pos, ID = 48930
# Sentimento = pos, ID = 48931
# Sentimento = pos, ID = 48932
# Sentimento = pos, ID = 48933
# Sentimento = pos, ID = 48934
# Sentimento = pos, ID = 48935
# Sentimento = pos, ID = 48936
# Sentimento = pos, ID = 48937
# Sentimento = pos, ID = 48938
# Sentimento = pos, ID = 48939
# Sentimento = pos, ID = 48940
# Sentimento = pos, ID = 48941
# Sentimento = pos, ID = 48942
# Sentimento = pos, ID = 48943
# Sentimento = pos, ID = 48944
# Sentimento = pos, ID = 48945
# Sentimento = pos, ID = 48946
# Sentimento = pos, ID = 48947
# Sentimento = pos, ID = 48948
# Sentimento = pos, ID = 48949
# Sentimento = pos, ID = 48950
# Sentimento = pos, ID = 48951
# Sentimento = pos, ID = 48952
# Sentimento = pos, ID = 48953
# Sentimento = pos, ID = 48954
# Sentimento = pos, ID = 48955
# Sentimento = pos, ID = 48956
# Sentimento = pos, ID = 48957
# Sentimento = pos, ID = 48958
# Sentimento = pos, ID = 48959
# Sentimento = pos, ID = 48960
# Sentimento = pos, ID = 48961
# Sentimento = pos, ID = 48962
# Sentimento = pos, ID = 48963
# Sentimento = pos, ID = 48964
# Sentimento = pos, ID = 48965
# Sentimento = pos, ID = 48966
# Sentimento = pos, ID = 48967
# Sentimento = pos, ID = 48968
# Sentimento = pos, ID = 48969
# Sentimento = pos, ID = 48970
# Sentimento = pos, ID = 48971
# Sentimento = pos, ID = 48972
# Sentimento = pos, ID = 48973
# Sentimento = pos, ID = 48974
# Sentimento = pos, ID = 48975
# Sentimento = pos, ID = 48976
# Sentimento = pos, ID = 48977
# Sentimento = pos, ID = 48978
# Sentimento = pos, ID = 48979
# Sentimento = pos, ID = 48980
# Sentimento = pos, ID = 48981
# Sentimento = pos, ID = 48982
# Sentimento = pos, ID = 48983
# Sentimento = pos, ID = 48984
# Sentimento = pos, ID = 48985
# Sentimento = pos, ID = 48986
# Sentimento = pos, ID = 48987
# Sentimento = pos, ID = 48988
# Sentimento = pos, ID = 48989
# Sentimento = pos, ID = 48990
# Sentimento = pos, ID = 48991
# Sentimento = pos, ID = 48992
# Sentimento = pos, ID = 48993
# Sentimento = pos, ID = 48994
# Sentimento = pos, ID = 48995
# Sentimento = pos, ID = 48996
# Sentimento = pos, ID = 48997
# Sentimento = pos, ID = 48998
# Sentimento = pos, ID = 48999
# Sentimento = pos, ID = 49000
# Sentimento = pos, ID = 49001
# Sentimento = pos, ID = 49002
# Sentimento = pos, ID = 49003
# Sentimento = pos, ID = 49004
# Sentimento = pos, ID = 49005
# Sentimento = pos, ID = 49006
# Sentimento = pos, ID = 49007
# Sentimento = pos, ID = 49008
# Sentimento = pos, ID = 49009
# Sentimento = pos, ID = 49010
# Sentimento = pos, ID = 49011
# Sentimento = pos, ID = 49012
# Sentimento = pos, ID = 49013
# Sentimento = pos, ID = 49014
# Sentimento = pos, ID = 49015
# Sentimento = pos, ID = 49016
# Sentimento = pos, ID = 49017
# Sentimento = pos, ID = 49018
# Sentimento = pos, ID = 49019
# Sentimento = pos, ID = 49020
# Sentimento = pos, ID = 49021
# Sentimento = pos, ID = 49022
# Sentimento = pos, ID = 49023
# Sentimento = pos, ID = 49024
# Sentimento = pos, ID = 49025
# Sentimento = pos, ID = 49026
# Sentimento = pos, ID = 49027
# Sentimento = pos, ID = 49028
# Sentimento = pos, ID = 49029
# Sentimento = pos, ID = 49030
# Sentimento = pos, ID = 49031
# Sentimento = pos, ID = 49032
# Sentimento = pos, ID = 49033
# Sentimento = pos, ID = 49034
# Sentimento = pos, ID = 49035
# Sentimento = pos, ID = 49036
# Sentimento = pos, ID = 49037
# Sentimento = pos, ID = 49038
# Sentimento = pos, ID = 49039
# Sentimento = pos, ID = 49040
# Sentimento = pos, ID = 49041
# Sentimento = pos, ID = 49042
# Sentimento = pos, ID = 49043
# Sentimento = pos, ID = 49044
# Sentimento = pos, ID = 49045
# Sentimento = pos, ID = 49046
# Sentimento = pos, ID = 49047
# Sentimento = pos, ID = 49048
# Sentimento = pos, ID = 49049
# Sentimento = pos, ID = 49050
# Sentimento = pos, ID = 49051
# Sentimento = pos, ID = 49052
# Sentimento = pos, ID = 49053
# Sentimento = pos, ID = 49054
# Sentimento = pos, ID = 49055
# Sentimento = pos, ID = 49056
# Sentimento = pos, ID = 49057
# Sentimento = pos, ID = 49058
# Sentimento = pos, ID = 49059
# Sentimento = pos, ID = 49060
# Sentimento = pos, ID = 49061
# Sentimento = pos, ID = 49062
# Sentimento = pos, ID = 49063
# Sentimento = pos, ID = 49064
# Sentimento = pos, ID = 49065
# Sentimento = pos, ID = 49066
# Sentimento = pos, ID = 49067
# Sentimento = pos, ID = 49068
# Sentimento = pos, ID = 49069
# Sentimento = pos, ID = 49070
# Sentimento = pos, ID = 49071
# Sentimento = pos, ID = 49072
# Sentimento = pos, ID = 49073
# Sentimento = pos, ID = 49074
# Sentimento = pos, ID = 49075
# Sentimento = pos, ID = 49076
# Sentimento = pos, ID = 49077
# Sentimento = pos, ID = 49078
# Sentimento = pos, ID = 49079
# Sentimento = pos, ID = 49080
# Sentimento = pos, ID = 49081
# Sentimento = pos, ID = 49082
# Sentimento = pos, ID = 49083
# Sentimento = pos, ID = 49084
# Sentimento = pos, ID = 49085
# Sentimento = pos, ID = 49086
# Sentimento = pos, ID = 49087
# Sentimento = pos, ID = 49088
# Sentimento = pos, ID = 49089
# Sentimento = pos, ID = 49090
# Sentimento = pos, ID = 49091
# Sentimento = pos, ID = 49092
# Sentimento = pos, ID = 49093
# Sentimento = pos, ID = 49094
# Sentimento = pos, ID = 49095
# Sentimento = pos, ID = 49096
# Sentimento = pos, ID = 49097
# Sentimento = pos, ID = 49098
# Sentimento = pos, ID = 49099
# Sentimento = pos, ID = 49100
# Sentimento = pos, ID = 49101
# Sentimento = pos, ID = 49102
# Sentimento = pos, ID = 49103
# Sentimento = pos, ID = 49104
# Sentimento = pos, ID = 49105
# Sentimento = pos, ID = 49106
# Sentimento = pos, ID = 49107
# Sentimento = pos, ID = 49108
# Sentimento = pos, ID = 49109
# Sentimento = pos, ID = 49110
# Sentimento = pos, ID = 49111
# Sentimento = pos, ID = 49112
# Sentimento = pos, ID = 49113
# Sentimento = pos, ID = 49114
# Sentimento = pos, ID = 49115
# Sentimento = pos, ID = 49116
# Sentimento = pos, ID = 49117
# Sentimento = pos, ID = 49118
# Sentimento = pos, ID = 49119
# Sentimento = pos, ID = 49120
# Sentimento = pos, ID = 49121
# Sentimento = pos, ID = 49122
# Sentimento = pos, ID = 49123
# Sentimento = pos, ID = 49124
# Sentimento = pos, ID = 49125
# Sentimento = pos, ID = 49126
# Sentimento = pos, ID = 49127
# Sentimento = pos, ID = 49128
# Sentimento = pos, ID = 49129
# Sentimento = pos, ID = 49130
# Sentimento = pos, ID = 49131
# Sentimento = pos, ID = 49132
# Sentimento = pos, ID = 49133
# Sentimento = pos, ID = 49134
# Sentimento = pos, ID = 49135
# Sentimento = pos, ID = 49136
# Sentimento = pos, ID = 49137
# Sentimento = pos, ID = 49138
# Sentimento = pos, ID = 49139
# Sentimento = pos, ID = 49140
# Sentimento = pos, ID = 49141
# Sentimento = pos, ID = 49142
# Sentimento = pos, ID = 49143
# Sentimento = pos, ID = 49144
# Sentimento = pos, ID = 49145
# Sentimento = pos, ID = 49146
# Sentimento = pos, ID = 49147
# Sentimento = pos, ID = 49148
# Sentimento = pos, ID = 49149
# Sentimento = pos, ID = 49150
# Sentimento = pos, ID = 49151
# Sentimento = pos, ID = 49152
# Sentimento = pos, ID = 49153
# Sentimento = pos, ID = 49154
# Sentimento = pos, ID = 49155
# Sentimento = pos, ID = 49156
# Sentimento = pos, ID = 49157
# Sentimento = pos, ID = 49158
# Sentimento = pos, ID = 49159
# Sentimento = pos, ID = 49160
# Sentimento = pos, ID = 49161
# Sentimento = pos, ID = 49162
# Sentimento = pos, ID = 49163
# Sentimento = pos, ID = 49164
# Sentimento = pos, ID = 49165
# Sentimento = pos, ID = 49166
# Sentimento = pos, ID = 49167
# Sentimento = pos, ID = 49168
# Sentimento = pos, ID = 49169
# Sentimento = pos, ID = 49170
# Sentimento = pos, ID = 49171
# Sentimento = pos, ID = 49172
# Sentimento = pos, ID = 49173
# Sentimento = pos, ID = 49174
# Sentimento = pos, ID = 49175
# Sentimento = pos, ID = 49176
# Sentimento = pos, ID = 49177
# Sentimento = pos, ID = 49178
# Sentimento = pos, ID = 49179
# Sentimento = pos, ID = 49180
# Sentimento = pos, ID = 49181
# Sentimento = pos, ID = 49182
# Sentimento = pos, ID = 49183
# Sentimento = pos, ID = 49184
# Sentimento = pos, ID = 49185
# Sentimento = pos, ID = 49186
# Sentimento = pos, ID = 49187
# Sentimento = pos, ID = 49188
# Sentimento = pos, ID = 49189
# Sentimento = pos, ID = 49190
# Sentimento = pos, ID = 49191
# Sentimento = pos, ID = 49192
# Sentimento = pos, ID = 49193
# Sentimento = pos, ID = 49194
# Sentimento = pos, ID = 49195
# Sentimento = pos, ID = 49196
# Sentimento = pos, ID = 49197
# Sentimento = pos, ID = 49198
# Sentimento = pos, ID = 49199
# Sentimento = pos, ID = 49200
# Sentimento = pos, ID = 49201
# Sentimento = pos, ID = 49202
# Sentimento = pos, ID = 49203
# Sentimento = pos, ID = 49204
# Sentimento = pos, ID = 49205
# Sentimento = pos, ID = 49206
# Sentimento = pos, ID = 49207
# Sentimento = pos, ID = 49208
# Sentimento = pos, ID = 49209
# Sentimento = pos, ID = 49210
# Sentimento = pos, ID = 49211
# Sentimento = pos, ID = 49212
# Sentimento = pos, ID = 49213
# Sentimento = pos, ID = 49214
# Sentimento = pos, ID = 49215
# Sentimento = pos, ID = 49216
# Sentimento = pos, ID = 49217
# Sentimento = pos, ID = 49218
# Sentimento = pos, ID = 49219
# Sentimento = pos, ID = 49220
# Sentimento = pos, ID = 49221
# Sentimento = pos, ID = 49222
# Sentimento = pos, ID = 49223
# Sentimento = pos, ID = 49224
# Sentimento = pos, ID = 49225
# Sentimento = pos, ID = 49226
# Sentimento = pos, ID = 49227
# Sentimento = pos, ID = 49228
# Sentimento = pos, ID = 49229
# Sentimento = pos, ID = 49230
# Sentimento = pos, ID = 49231
# Sentimento = pos, ID = 49232
# Sentimento = pos, ID = 49233
# Sentimento = pos, ID = 49234
# Sentimento = pos, ID = 49235
# Sentimento = pos, ID = 49236
# Sentimento = pos, ID = 49237
# Sentimento = pos, ID = 49238
# Sentimento = pos, ID = 49239
# Sentimento = pos, ID = 49240
# Sentimento = pos, ID = 49241
# Sentimento = pos, ID = 49242
# Sentimento = pos, ID = 49243
# Sentimento = pos, ID = 49244
# Sentimento = pos, ID = 49245
# Sentimento = pos, ID = 49246
# Sentimento = pos, ID = 49247
# Sentimento = pos, ID = 49248
# Sentimento = pos, ID = 49249
# Sentimento = pos, ID = 49250
# Sentimento = pos, ID = 49251
# Sentimento = pos, ID = 49252
# Sentimento = pos, ID = 49253
# Sentimento = pos, ID = 49254
# Sentimento = pos, ID = 49255
# Sentimento = pos, ID = 49256
# Sentimento = pos, ID = 49257
# Sentimento = pos, ID = 49258
# Sentimento = pos, ID = 49259
# Sentimento = pos, ID = 49260
# Sentimento = pos, ID = 49261
# Sentimento = pos, ID = 49262
# Sentimento = pos, ID = 49263
# Sentimento = pos, ID = 49264
# Sentimento = pos, ID = 49265
# Sentimento = pos, ID = 49266
# Sentimento = pos, ID = 49267
# Sentimento = pos, ID = 49268
# Sentimento = pos, ID = 49269
# Sentimento = pos, ID = 49270
# Sentimento = pos, ID = 49271
# Sentimento = pos, ID = 49272
# Sentimento = pos, ID = 49273
# Sentimento = pos, ID = 49274
# Sentimento = pos, ID = 49275
# Sentimento = pos, ID = 49276
# Sentimento = pos, ID = 49277
# Sentimento = pos, ID = 49278
# Sentimento = pos, ID = 49279
# Sentimento = pos, ID = 49280
# Sentimento = pos, ID = 49281
# Sentimento = pos, ID = 49282
# Sentimento = pos, ID = 49283
# Sentimento = pos, ID = 49284
# Sentimento = pos, ID = 49285
# Sentimento = pos, ID = 49286
# Sentimento = pos, ID = 49287
# Sentimento = pos, ID = 49288
# Sentimento = pos, ID = 49289
# Sentimento = pos, ID = 49290
# Sentimento = pos, ID = 49291
# Sentimento = pos, ID = 49292
# Sentimento = pos, ID = 49293
# Sentimento = pos, ID = 49294
# Sentimento = pos, ID = 49295
# Sentimento = pos, ID = 49296
# Sentimento = pos, ID = 49297
# Sentimento = pos, ID = 49298
# Sentimento = pos, ID = 49299
# Sentimento = pos, ID = 49300
# Sentimento = pos, ID = 49301
# Sentimento = pos, ID = 49302
# Sentimento = pos, ID = 49303
# Sentimento = pos, ID = 49304
# Sentimento = pos, ID = 49305
# Sentimento = pos, ID = 49306
# Sentimento = pos, ID = 49307
# Sentimento = pos, ID = 49308
# Sentimento = pos, ID = 49309
# Sentimento = pos, ID = 49310
# Sentimento = pos, ID = 49311
# Sentimento = pos, ID = 49312
# Sentimento = pos, ID = 49313
# Sentimento = pos, ID = 49314
# Sentimento = pos, ID = 49315
# Sentimento = pos, ID = 49316
# Sentimento = pos, ID = 49317
# Sentimento = pos, ID = 49318
# Sentimento = pos, ID = 49319
# Sentimento = pos, ID = 49320
# Sentimento = pos, ID = 49321
# Sentimento = pos, ID = 49322
# Sentimento = pos, ID = 49323
# Sentimento = pos, ID = 49324
# Sentimento = pos, ID = 49325
# Sentimento = pos, ID = 49326
# Sentimento = pos, ID = 49327
# Sentimento = pos, ID = 49328
# Sentimento = pos, ID = 49329
# Sentimento = pos, ID = 49330
# Sentimento = pos, ID = 49331
# Sentimento = pos, ID = 49332
# Sentimento = pos, ID = 49333
# Sentimento = pos, ID = 49334
# Sentimento = pos, ID = 49335
# Sentimento = pos, ID = 49336
# Sentimento = pos, ID = 49337
# Sentimento = pos, ID = 49338
# Sentimento = pos, ID = 49339
# Sentimento = pos, ID = 49340
# Sentimento = pos, ID = 49341
# Sentimento = pos, ID = 49342
# Sentimento = pos, ID = 49343
# Sentimento = pos, ID = 49344
# Sentimento = pos, ID = 49345
# Sentimento = pos, ID = 49346
# Sentimento = pos, ID = 49347
# Sentimento = pos, ID = 49348
# Sentimento = pos, ID = 49349
# Sentimento = pos, ID = 49350
# Sentimento = pos, ID = 49351
# Sentimento = pos, ID = 49352
# Sentimento = pos, ID = 49353
# Sentimento = pos, ID = 49354
# Sentimento = pos, ID = 49355
# Sentimento = pos, ID = 49356
# Sentimento = pos, ID = 49357
# Sentimento = pos, ID = 49358
# Sentimento = pos, ID = 49359
# Sentimento = pos, ID = 49360
# Sentimento = pos, ID = 49361
# Sentimento = pos, ID = 49362
# Sentimento = pos, ID = 49363
# Sentimento = pos, ID = 49364
# Sentimento = pos, ID = 49365
# Sentimento = pos, ID = 49366
# Sentimento = pos, ID = 49367
# Sentimento = pos, ID = 49368
# Sentimento = pos, ID = 49369
# Sentimento = pos, ID = 49370
# Sentimento = pos, ID = 49371
# Sentimento = pos, ID = 49372
# Sentimento = pos, ID = 49373
# Sentimento = pos, ID = 49374
# Sentimento = pos, ID = 49375
# Sentimento = pos, ID = 49376
# Sentimento = pos, ID = 49377
# Sentimento = pos, ID = 49378
# Sentimento = pos, ID = 49379
# Sentimento = pos, ID = 49380
# Sentimento = pos, ID = 49381
# Sentimento = pos, ID = 49382
# Sentimento = pos, ID = 49383
# Sentimento = pos, ID = 49384
# Sentimento = pos, ID = 49385
# Sentimento = pos, ID = 49386
# Sentimento = pos, ID = 49387
# Sentimento = pos, ID = 49388
# Sentimento = pos, ID = 49389
# Sentimento = pos, ID = 49390
# Sentimento = pos, ID = 49391
# Sentimento = pos, ID = 49392
# Sentimento = pos, ID = 49393
# Sentimento = pos, ID = 49394
# Sentimento = pos, ID = 49395
# Sentimento = pos, ID = 49396
# Sentimento = pos, ID = 49397
# Sentimento = pos, ID = 49398
# Sentimento = pos, ID = 49399
# Sentimento = pos, ID = 49400
# Sentimento = pos, ID = 49401
# Sentimento = pos, ID = 49402
# Sentimento = pos, ID = 49403
# Sentimento = pos, ID = 49404
# Sentimento = pos, ID = 49405
# Sentimento = pos, ID = 49406
# Sentimento = pos, ID = 49407
# Sentimento = pos, ID = 49408
# Sentimento = pos, ID = 49409
# Sentimento = pos, ID = 49410
# Sentimento = pos, ID = 49411
# Sentimento = pos, ID = 49412
# Sentimento = pos, ID = 49413
# Sentimento = pos, ID = 49414
# Sentimento = pos, ID = 49415
# Sentimento = pos, ID = 49416
# Sentimento = pos, ID = 49417
# Sentimento = pos, ID = 49418
# Sentimento = pos, ID = 49419
# Sentimento = pos, ID = 49420
# Sentimento = pos, ID = 49421
# Sentimento = pos, ID = 49422
# Sentimento = pos, ID = 49423
# Sentimento = pos, ID = 49424
# Sentimento = pos, ID = 49425
# Sentimento = pos, ID = 49426
# Sentimento = pos, ID = 49427
# Sentimento = pos, ID = 49428
# Sentimento = pos, ID = 49429
# Sentimento = pos, ID = 49430
# Sentimento = pos, ID = 49431
# Sentimento = pos, ID = 49432
# Sentimento = pos, ID = 49433
# Sentimento = pos, ID = 49434
# Sentimento = pos, ID = 49435
# Sentimento = pos, ID = 49436
# Sentimento = pos, ID = 49437
# Sentimento = pos, ID = 49438
# Sentimento = pos, ID = 49439
# Sentimento = pos, ID = 49440
# Sentimento = pos, ID = 49441
# Sentimento = pos, ID = 49442
# Sentimento = pos, ID = 49443
# Sentimento = pos, ID = 49444
# Sentimento = pos, ID = 49445
# Sentimento = pos, ID = 49446
# Sentimento = pos, ID = 49447
# Sentimento = pos, ID = 49448
# Sentimento = pos, ID = 49449
# Sentimento = pos, ID = 49450
# Sentimento = pos, ID = 49451
# Sentimento = pos, ID = 49452
# Sentimento = pos, ID = 49453
# Sentimento = pos, ID = 49454
# Sentimento = pos, ID = 49455
# Sentimento = pos, ID = 49456
# Sentimento = pos, ID = 49457
# Sentimento = pos, ID = 49458
# Sentimento = pos, ID = 49459
# Sentimento = pos, ID = 49460

# %% [markdown]
# ## Cria funções de REDUCE:
#
# - Criar função de reduce para somar os IDs por "sentiment".
#
# A função reduce irá somar os valores dos IDs agrupados por chave ('sentiment').

# %%
def reduceByKey1(x,y):
  # Coloque aqui o seu código para retornar o resultado necessário.
  # x e y são valores que serão somados, pois o reduceByKey receberá
  # apenas o segundo elemento da tupla vinda da saída da função map.
  # Apague a linha abaixo para iniciar seu código.
  pass

# %% [markdown]
# ## Aplicação do map/reduce e visualização do resultado
#
# Aqui, você aplicará as funções de map e reduce ao dataframe Spark para calcular os resultados. Não se esqueça de usar o método `.collect()` para visualizar os resultados.

# %%
# Linha de código para aplicar o map/reduce no seu dataframe spark
resultado = imdb_df.rdd.map(map1).reduceByKey(reduceByKey1).collect()
# Coloque aqui o código para imprimir o resultado. Não esqueça seu RU:

# %% [markdown]
# # Questão 2:
#
# Nesta questão, você irá calcular a diferença no número total de palavras entre textos negativos em português e inglês.
#
# ### Objetivo:
# - Contar as palavras em cada idioma (colunas 'text_pt' e 'text_en') para entradas onde o sentimento ('sentiment') é 'neg'.
# - Subtrair o total de palavras em inglês do total em português.

# %% [markdown]
# ## Criar funções de MAP:
# - Criar função para mapear o "sentiment" como chave de uma tupla principal e como valor uma outra tupla com a soma das palavras de cada idioma como valor.
#
# A função map irá transformar cada linha do dataframe em uma tupla (chave-valor), onde:
# - Chave: coluna 'sentiment'
# - Valor: Nova tupla com:
#   - Elemento 0: soma das palavras da coluna 'text_en'
#   - Elemento 1: soma das palavras da coluna 'text_pt'
#
# OU
# - Chave: coluna 'sentiment'
# - Valor: (soma das palavras da coluna 'text_pt') - (soma das palavras da coluna 'text_en')
#
#
# Para contar as palavras deve-se primeiro separar os textos em uma lista de palavras para então descobrir o tamanho desta lista.
# Dicas:
#
# 1. Use o método .split() e não .split(" ") de string para separar as palavras em uma lista ou use a função split(coluna de texto, regex) do pyspark com o regex igual à "[ ]+" ou "\s+"
# 2. Use len() para descobrir o tamanho da lista de palavras.

# %%
def map2(x):
  # Coloque aqui o seu código para retornar a tupla necessária.
  # Sugerimos o retorno em uma tupla com este formato:
  #   (sentiment, (quantidade_de_palavras_em_en, quantidade_de_palavras_em_pt))
  #   OU
  #   (sentiment, quantidade_de_caracteres_em_pt-quantidade_de_caracteres_em_en)
  # Apague a linha abaixo para iniciar seu código.
  pass

# %% [markdown]
# ## Cria funções de REDUCE:
#
# - Criar função de reduce para somar o numero de palavras de cada texto português e inglês por "sentiment" (dependerá de como você optou por fazer sua função map2).
#
# A função reduce irá somar os valores das quantidades de palavras agrupados por chave ('sentiment').

# %%
def reduceByKey2(x,y):
  # Coloque aqui o seu código para retornar o resultado necessário.
  # x e y são valores que podem ser ou a tupla vinda da saída da função map
  # contendo quantidade de palavras em inglês e português, ou a diferença, a
  # depender da sua implementação da função map2.
  # Apague a linha abaixo para iniciar seu código.
  pass

# %% [markdown]
# ## Aplicação do map/reduce e visualização do resultado
#
# 1. Aplicar o map/reduce no seu dataframe spark e realizar o collect() ao final
# 2. Selecionar os dados referentes aos textos negativos para realizar a subtração.
# 3. Realizar a subtração das contagens de palavras dos textos negativos para obter o resultado final

# %%
# Linha de código para aplicar o map/reduce no seu dataframe spark
resultado = imdb_df.rdd.map(map2).reduceByKey(reduceByKey2).collect()
# Coloque aqui suas linhas de código final para imprimir o resultado.
# Não esqueça seu RU:
